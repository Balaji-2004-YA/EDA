# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
import pandas as pd

# %%
        df = pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Information about the Dataset

# %%
print(f" No. of Rows in the Dataset: {df.shape[0]}")
# Out:
#  No. of Rows in the Dataset: 10841

# %%
print(f" No. of Columns in the Dataset: {df.shape[1]}")
# Out:
#  No. of Columns in the Dataset: 13

# %%
print(f" Data Types in Dataset: {"\n"} {df.dtypes}")
# Out:
#  Data Types in Dataset:
#  App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
print(f"Top 5 records in the Dataset: {"\n"} {df.head()}")
# Out:
# Top 5 records in the Dataset:
#                                                   App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
print(f"Last 5 records in the Dataset: {"\n"} {df.tail()}")
# Out:
# Last 5 records in the Dataset:
#                                                   App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# Statistical Summary about Numerical Column
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Statistical Summary for all the columns

df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
print(f"Info about the Dataset: {df.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# Info about the Dataset: None

# %%
# Finding the missing values
print(f"Missing values column wise: {"\n"}  {df.isnull().sum()}")
# Out:
# Missing values column wise:
#   App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
pip install missingno
# Out:
# ...
#
# ...

# %%
# Visualizing Missing Values
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
# Handling the Missing Values

# %%
df['Rating']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Rating']
#
# NameError: name 'df' is not defined

# %%
# # The function to Detect outliers

# def detect_outliers_using_five_number_summary(dataframe, column_name):
#     """
#     Detects outliers in  a DataFrame column using the five-number summary and IQR method.
#     Returns a list of outliers
#     """
#     # Calculate the Five Number Summary
#     Q1 = df[column_name].quantile(0.25)
#     Q3 = df[column_name].quantile(0.75)

#     # Interquartile Range
#     IQR = Q3 - Q1 

#     # Defining the lower and  Higher Bounds for outliers
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR

#     # Identify Outliers
#     outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)][column_name].tolist()
#     # 
#     print(f"Five-Number Summary for {column_name}:")
#     print(f"Min: {df[column_name].min()}, Q1: {Q1}, Median: {df[column_name].median()}, Q3: {Q3}, Max: {df[column_name].max()}")
#     print(f"IQR: {IQR}")
#     print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
#     print(f"Outliers: {outliers}")
    
#     # return outliers

# %%
# detect_outliers_using_five_number_summary(df, 'Rating')

# %% [markdown]
# ### Handling Missing Values

# %%
df[df["Rating"] > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df["Rating"] = df["Rating"].fillna(Rating_median_value)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df[df['Rating'] > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Drop Rows with Invalid Rating values in Rating Column

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df["Installs"] = df["Installs"].str.replace('[+, ]', '', regex=True)

# %%
df["Installs"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10841, dtype: object

# %%
df["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
df.drop(index=df[df['Rating'] == 19.0].index, inplace=True)

# %%
df[df['Rating'] > 5]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.drop(index=df[df['Type'] == "Free"].index, inplace=True)

# %%
df.drop(index=df[df['Installs'] == "Free"].index, inplace=True)

# %%
df["Installs"].unique()
# Out:
# array(['100000', '10000', '1000', '50', '100', '500000', '50000', '5000',
#        '500', '10000000', '1000000', '1', '10', '5', '0'], dtype=object)

# %%
# Covert Installs Datatypes from Object to Int

# %%
df['Installs'] = pd.to_numeric(df["Installs"], errors="coerce")

# %%
df["Installs"].unique()
# Out:
# array([  100000,    10000,     1000,       50,      100,   500000,
#           50000,     5000,      500, 10000000,  1000000,        1,
#              10,        5,        0], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 234 to 10798
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             801 non-null    object
#  1   Category        801 non-null    object
#  2   Rating          801 non-null    float64
#  3   Reviews         801 non-null    object
#  4   Size            801 non-null    object
#  5   Installs        801 non-null    int64
#  6   Type            800 non-null    object
#  7   Price           801 non-null    object
#  8   Content Rating  801 non-null    object
#  9   Genres          801 non-null    object
#  10  Last Updated    801 non-null    object
#  11  Current Ver     799 non-null    object
#  12  Android Ver     800 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 87.6+ KB

# %%
df.head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 290  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 291                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
#
#     Reviews                Size  Installs  Type  Price Content Rating  \
# 234   11442                6.8M    100000  Paid  $4.99       Everyone
# 235   10295                 39M    100000  Paid  $4.99       Everyone
# 290   11442                6.8M    100000  Paid  $4.99       Everyone
# 291   10295                 39M    100000  Paid  $4.99       Everyone
# 427   18247  Varies with device    100000  Paid  $3.99       Everyone
#
#             Genres    Last Updated  Current Ver Android Ver
# ...

# %%
# Price Feature

# %%
df["Price"] = df["Price"].str.replace('[$,]','', regex=True )

# %%
df["Price"]
# Out:
# 234       4.99
# 235       4.99
# 290       4.99
# 291       4.99
# 427       3.99
#          ...
# 10735     0.99
# 10760     7.99
# 10782    16.99
# 10785     1.20
# 10798     1.04
# Name: Price, Length: 801, dtype: object

# %%
# Covert Price Datatypes from Object to Int

# %%
df["Price"] = pd.to_numeric(df["Price"], errors = "coerce")

# %%
df["Price"]
# Out:
# 234       4.99
# 235       4.99
# 290       4.99
# 291       4.99
# 427       3.99
#          ...
# 10735     0.99
# 10760     7.99
# 10782    16.99
# 10785     1.20
# 10798     1.04
# Name: Price, Length: 801, dtype: float64

# %%
df.head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 290  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 291                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
#
#     Reviews                Size  Installs  Type  Price Content Rating  \
# 234   11442                6.8M    100000  Paid   4.99       Everyone
# 235   10295                 39M    100000  Paid   4.99       Everyone
# 290   11442                6.8M    100000  Paid   4.99       Everyone
# 291   10295                 39M    100000  Paid   4.99       Everyone
# 427   18247  Varies with device    100000  Paid   3.99       Everyone
#
#             Genres    Last Updated  Current Ver Android Ver
# ...

# %% [markdown]
# # Assignment
#     1. Clean the Size Feature and Change the Data Type.
#     2. Clean Current Version feature and check data type.
#     3. Clean Reviews Feature.
#     4. Clean Last Updated Feature.

# %%
df["Reviews"].unique()
# Out:
# array(['11442', '10295', '18247', '1545', '57', '0', '4', '2', '1546',
#        '11', '21', '31085', '3528', '6238', '3771', '2129', '1268',
#        '2107', '1026', '19543', '18621', '19922', '21119', '7412',
#        '18125', '10795', '13004', '38207', '9394', '96', '169', '8',
#        '3328', '31100', '854', '560', '197', '30', '97', '38', '214',
#        '248', '185', '2195', '1615', '359', '73', '382', '253', '3396',
#        '2376564', '129603', '1135', '578', '129', '63', '216', '171',
#        '45', '717', '2921', '1533', '92', '199', '1361', '12', '15',
#        '206', '395', '79', '3', '35', '77', '51', '104', '80', '10',
#        '156', '178', '576', '168', '25', '163', '319', '133', '9', '74',
#        '4207', '17', '358', '726', '33', '492', '41', '625', '64', '66',
#        '6', '49553', '12865', '16320', '3387', '97890', '58617', '1591',
#        '881', '40704', '26919', '17493', '7', '291', '83', '24', '2890',
# ...

# %%
df['Last Updated'].unique()
# Out:
# array(['March 25, 2018', 'April 11, 2017', 'July 5, 2018',
#        'June 19, 2018', 'October 25, 2017', 'September 1, 2017',
#        'July 25, 2017', 'August 2, 2018', 'January 21, 2017',
#        'July 24, 2017', 'July 21, 2017', 'July 6, 2018', 'June 12, 2018',
#        'June 30, 2018', 'August 3, 2018', 'June 28, 2018', 'June 3, 2018',
#        'December 22, 2015', 'May 15, 2018', 'January 19, 2018',
#        'July 4, 2018', 'July 30, 2018', 'April 18, 2018',
#        'April 26, 2018', 'July 9, 2018', 'December 21, 2017',
#        'December 20, 2016', 'October 19, 2015', 'November 30, 2017',
#        'June 14, 2018', 'May 25, 2018', 'June 25, 2018', 'July 13, 2017',
#        'December 1, 2015', 'June 17, 2015', 'March 23, 2017',
#        'May 16, 2018', 'March 30, 2018', 'September 3, 2015',
#        'November 14, 2014', 'December 13, 2017', 'July 24, 2018',
#        'May 1, 2018', 'August 2, 2016', 'February 9, 2016',
# ...

# %% [markdown]
# ### Univariate Analysis - Analysing Single Feature

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df["Rating"]
# Out:
# 234      4.7
# 235      4.8
# 290      4.7
# 291      4.8
# 427      4.0
#         ...
# 10735    4.3
# 10760    4.4
# 10782    3.8
# 10785    4.2
# 10798    4.3
# Name: Rating, Length: 801, dtype: float64

# %%
sns.histplot(df["Rating"], kde=True)
plt.title("Distribution of Ratings")
plt.show()

# %%
# Category Distribution

category_counts = df['Category'].value_counts()
category_counts.plot(kind="bar", figsize=(10,5), title="App Category Distribution")
plt.show()

# %% [markdown]
# ### Bivariate Analysis - Analyzing relationships b/w two variables

# %%
df['Rating']
# Out:
# 234      4.7
# 235      4.8
# 290      4.7
# 291      4.8
# 427      4.0
#         ...
# 10735    4.3
# 10760    4.4
# 10782    3.8
# 10785    4.2
# 10798    4.3
# Name: Rating, Length: 801, dtype: float64

# %%
df["Reviews"].unique()
# Out:
# array(['11442', '10295', '18247', '1545', '57', '0', '4', '2', '1546',
#        '11', '21', '31085', '3528', '6238', '3771', '2129', '1268',
#        '2107', '1026', '19543', '18621', '19922', '21119', '7412',
#        '18125', '10795', '13004', '38207', '9394', '96', '169', '8',
#        '3328', '31100', '854', '560', '197', '30', '97', '38', '214',
#        '248', '185', '2195', '1615', '359', '73', '382', '253', '3396',
#        '2376564', '129603', '1135', '578', '129', '63', '216', '171',
#        '45', '717', '2921', '1533', '92', '199', '1361', '12', '15',
#        '206', '395', '79', '3', '35', '77', '51', '104', '80', '10',
#        '156', '178', '576', '168', '25', '163', '319', '133', '9', '74',
#        '4207', '17', '358', '726', '33', '492', '41', '625', '64', '66',
#        '6', '49553', '12865', '16320', '3387', '97890', '58617', '1591',
#        '881', '40704', '26919', '17493', '7', '291', '83', '24', '2890',
# ...

# %%
df["Reviews"] = pd.to_numeric(df["Reviews"], errors="coerce")

# %%
df["Reviews"].unique()
# Out:
# array([  11442,   10295,   18247,    1545,      57,       0,       4,
#              2,    1546,      11,      21,   31085,    3528,    6238,
#           3771,    2129,    1268,    2107,    1026,   19543,   18621,
#          19922,   21119,    7412,   18125,   10795,   13004,   38207,
#           9394,      96,     169,       8,    3328,   31100,     854,
#            560,     197,      30,      97,      38,     214,     248,
#            185,    2195,    1615,     359,      73,     382,     253,
#           3396, 2376564,  129603,    1135,     578,     129,      63,
#            216,     171,      45,     717,    2921,    1533,      92,
#            199,    1361,      12,      15,     206,     395,      79,
#              3,      35,      77,      51,     104,      80,      10,
#            156,     178,     576,     168,      25,     163,     319,
#            133,       9,      74,    4207,      17,     358,     726,
# ...

# %%
# Scatter plot for Rating and Reviews

# %%
sns.scatterplot(x="Reviews", y="Rating", data=df)
plt.title(" Reviews vs Rating ")
plt.show()

# %%
# Boxplot for Rating and Category

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="Category", y="Rating", data=df)
plt.xticks(rotation=90)
plt.title("Rating by Category")
plt.show()

# %% [markdown]
# ### Multivariante Analysis - Exploring interactions b/w multiple variables

# %%
sns.pairplot(df[['Rating', 'Reviews', 'Installs', 'Price']])
plt.show()

# %%
sns.pairplot(df)
